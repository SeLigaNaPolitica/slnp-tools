# %% [markdown]
# ## Requirements

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cv2
import face_detect as fd
import face_emb as fe
import util as ut

# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Loading pre-trained facenet model
# Model filename: 20180408-102900/20180408-102900.pb

# %% [markdown]
# ## Step 1 - Face detection

# %%
hlFacesImg, segImgList = fd.face_detect("images/img1.png")

# %%
#print highlighted faces
plt.imshow(hlFacesImg)
plt.show()

# %%
#print each segmented face
for index, face_img in enumerate(segImgList):
    print("Face", index)
    plt.imshow(face_img)
    plt.show()
# Out:
# Face 0
# Face 1
# Face 2
# Face 3

# %% [markdown]
# ## Step 2 - Face Recognition

# %%
person_dict = ut.load_database("database")
# Out:
# Registering reference facial images in database ...
# database/bebiano/img1.png
# database/bebiano/img2.png
# database/bebiano/img3.png
# database/bebiano/img4.png
# database/bebiano/img5.png
# database/ernesto_araujo/img1.png
# database/ernesto_araujo/img2.png
# database/ernesto_araujo/img3.png
# database/ernesto_araujo/img4.png
# database/ernesto_araujo/img5.png
# database/jair_bolsonaro/img1.png
# database/jair_bolsonaro/img2.png
# database/jair_bolsonaro/img3.png
# database/jair_bolsonaro/img4.png
# database/jair_bolsonaro/img5.png
# database/paulo_guedes/img1.png
# database/paulo_guedes/img2.png
# database/paulo_guedes/img3.png
# database/paulo_guedes/img4.png
# database/paulo_guedes/img5.png

# %%
for index, face_img in enumerate(segImgList):
    print("Who is face", index)
    emb = fe.get_embedding(face_img)
    person_id = ut.who_is(person_dict, emb, top=6)
    print(person_id)
# Out:
# Who is face 0
# ('ernesto_araujo', 0.6666666666666666)
# Who is face 1
# ('jair_bolsonaro', 0.5)
# Who is face 2
# ('paulo_guedes', 0.3333333333333333)
# Who is face 3
# ('bebiano', 0.3333333333333333)
